# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/karla-udiljak-j68emx/deployments/vti0gg3z"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x1162b9bd0>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x1162bb750>
# The classic “how much wood …?” line is really just a tongue‑twister—groundhogs (woodchucks) are herbivores and don’t actually chuck timber.  But if we pretend they could, a back‑of‑the‑envelope calculation (treating a woodchuck’s burrowing “work‑capacity” as if it applied to wood) yields a ballpark figure:
#
# * **≈ 700 lb (≈ 320 kg) of wood**, which is about **one‑third of a cord** (a cord is 128 ft³ ≈ 3.6 m³).
#
# So, in a whimsical “if a woodchuck could chuck wood” world, it would be able to haul roughly a few hundred pounds—enough for a modest pile of firewood, but not a whole forest.

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x1162e5e80>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x11666ed50>
# Response 4: The classic tongue‑twister is really just a playful bit of n...
# Response 7: The classic, tongue‑twisting answer is:
#
# > “As much wood as ...
# Response 12: The classic tongue‑twister answer is circular on purpose:
#
# >...
# Response 6: The classic tongue‑twister answer is actually built right in...
# Response 10: The classic tongue‑twister answer is: **“As much wood as a w...
# Response 2: The real‑world answer is **none** – a “woodchuck” (a groundh...
# Response 18: The classic tongue‑twister answer is, of course, “as much wo...
# Response 3: The classic tongue‑twister is really more of a playful puzzl...
# Response 22: The short, tongue‑twister answer is: **zero**. A woodchuck (...
# Response 11: The classic tongue‑twister answer is:
#
# **“A woodchuck woul...
# Response 15: The classic tongue‑twister answer is:
#
# > “A woodchuck would ...
# Response 16: The classic (and perfectly circular) answer is:
#
# **“As much ...
# Response 17: A wood‑chuck would chuck **as much wood as a wood‑chuck coul...
# Response 23: The classic answer is the tongue‑twister itself:
#
# **“A woo...
# Response 20: The classic “tongue‑twister” answer is that a woodchuck coul...
# Response 1: The classic answer to the tongue‑twister is basically a play...
# Response 24: The classic “tongue‑twister” answer is a circular, self‑refe...
# Response 8: The line is a classic tongue‑twister, so the “real” answer i...
# Response 13: The classic answer to the old tongue‑twister is:
#
# > *“A wood...
# Response 5: The classic answer to the old tongue‑twister is really just ...
# Response 9: **Answer for Request 9**
#
# The classic tongue‑twister answer ...
# Response 14: **Answer (Request 14):**
#
# A woodchuck would “chuck” as muc...
# Response 21: The classic tongue‑twister answer is the only really “correc...
# Response 19: A woodchuck would chuck **as much wood as a woodchuck could ...
